# %%
import pandas as pd
import numpy as np

# %%
processed_features = pd.read_hdf("processed_features.h5", key="features")

# Display the first few rows
processed_features
# Out:
#                             0         1         2         3         4   \
# 10573461572310657861 -0.067864 -0.377810 -0.370083 -0.070223 -0.070061
# 10573461572310657862 -0.068375 -0.377810 -0.879263 -0.070223 -0.070061
# 10573461572310657863 -0.068631 -0.377810 -1.291814 -0.070223 -0.070061
# 6983161399497124298  -0.067923 -1.623507 -0.616094 -0.070291 -0.070140
# 6983161399497124299  -0.068415 -1.623507 -1.349297 -0.070291 -0.070140
# ...                        ...       ...       ...       ...       ...
# 4285894207192834973  -0.065278  1.256345  0.882070 -0.069412 -0.069435
# 4285894207192834974  -0.066308  1.256345  0.403257 -0.069771 -0.069614
# 5347820895146747720  -0.063558 -0.244831  1.968822 -0.067017 -0.067019
# 5347820895146747721  -0.065504 -0.244831  0.472525 -0.067371 -0.068064
# 5347820895146747722  -0.066477 -0.244831  0.199794 -0.068473 -0.068394
#
#                             5         6         7         8         9   ...  \
# ...

# %%
features_info = pd.read_hdf("feature_vectors.hdf", key="features")
features_info
# Out:
#                       charge  precursor_mz   rt_pred  mobility_pred  \
# 10573461572310657861       2    482.274170  0.376854       0.836941
# 10573461572310657862       3    321.851872  0.376854       0.707333
# 10573461572310657863       4    241.640723  0.376854       0.602321
# 6983161399497124298        2    463.685690  0.000000       0.774321
# 6983161399497124299        3    309.459552  0.000000       0.587689
# ...                      ...           ...       ...            ...
# 4285894207192834973        3   1294.267003  0.871227       1.155668
# 4285894207192834974        4    970.952072  0.871227       1.033790
# 5347820895146747720        2   1834.303920  0.417084       1.432294
# 5347820895146747721        3   1223.205039  0.417084       1.051421
# 5347820895146747722        4    917.655598  0.417084       0.982000
#
#                         frag_mz_1    frag_mz_2    frag_mz_3    frag_mz_4  \
# 10573461572310657861   835.482483   817.435547   670.367126   649.403198
# ...

# %%
index_to_hash = np.array(features_info.index.tolist())  # Convert mod_seq_charge_hash to a NumPy array
# D, I = faiss_index.search(query_vector, k)  # Returns distances (D) and indices (I)
# retrieved_hashes = index_to_hash[I]  # Convert FAISS indices back to mod_seq_charge_hash
# retrieved_vectors = feature_df.loc[retrieved_hashes]  # Get full feature vectors
# Out:
# pandas.core.indexes.base.Index
